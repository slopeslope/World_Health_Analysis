# %%
import pandas as pd

hotel_df = pd.read_csv("WeatherPy_vacation.csv")
hotel_df.head(50)
# Out:
#     City            City.1 Country  Max Temp Weather Description    Lat  \
# 0      2            Albany      US     84.00           clear sky  42.60
# 1      7            Bethel      US     82.40           clear sky  41.37
# 2     11         Hithadhoo      MV     84.83       broken clouds  -0.60
# 3     14        Butaritari      KI     83.71       broken clouds   3.07
# 4     29             Basco      PH     84.76       broken clouds  20.45
# 5     38            Garowe      SO     77.90       broken clouds   8.41
# 6     47          Kandiaro      PK     89.80           clear sky  27.06
# 7     51        The Valley      AI     84.20    scattered clouds  18.22
# 8     59          Kalmunai      LK     80.19     overcast clouds   7.42
# 9     60              Hilo      US     82.40          few clouds  19.73
# 10    74            Awbari      LY     84.24           clear sky  26.59
# 11    79       Trincomalee      LK     80.65     overcast clouds   8.57
# ...

# %%
#data frames
avera_df = hotel_df.loc[hotel_df["City.1"]=="Avera"] 
virginia_beach_df = hotel_df.loc[hotel_df["City.1"]=="Virginia Beach"]
marion_df =  hotel_df.loc[hotel_df["City.1"]=="Marion"]
windsor_df =  hotel_df.loc[hotel_df["City.1"]=="Windsor"]
windsor_df
# Out:
#      City   City.1 Country  Max Temp Weather Description   Lat    Lng  \
# 131   481  Windsor      CA      82.0    scattered clouds  42.3 -83.02
#
#      Hotel Name
# 131         NaN

# %%
import gmaps
import gmaps.datasets
import requests
# Import the API key.
from config import g_key 

# configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

#lat-long
avera = (33.19,-82.53)
virginia_beach = (36.85, -75.98)
mairon = (39.77, -86.16)
windsor = (42.2, -83.02)

fig = gmaps.figure()
fourcities = gmaps.directions_layer(avera, virginia_beach, waypoints=[mairon, windsor], travel_mode='DRIVING')
fig.add_layer(fourcities)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
